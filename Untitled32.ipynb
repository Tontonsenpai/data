# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

df=pd.read_csv("\\Users\\Administrator\\Desktop\\showwcase_sessions.csv")
df.head(10)
# Out:
#    session_id  customer_id login_date projects_added likes_given  \
# 0    624205.0      80746.0   10/30/19          False        True
# 1    624241.0      24520.0   10/30/19           True        True
# 2    111002.0      32047.0   10/30/19           True        True
# 3    545113.0      23404.0   10/30/19           True        True
# 4    750269.0      40235.0   10/30/19           True        True
# 5    744943.0      73245.0   10/30/19           True        True
# 6    922001.0      12407.0   10/30/19           True       False
# 7    823895.0      29375.0   10/30/19          False       False
# 8    490096.0      40572.0   10/30/19           True        True
# 9    919319.0      23404.0   10/29/19           True        True
#
#   comment_given inactive_status bug_occured  session_projects_added  \
# 0          True            True       False                     0.0
# 1          True            True       False                     2.0
# ...

# %%
df['duration_time']= df['session_duration']-df['inactive_duration']
neg_duration=df[df['duration_time'] < 0].index
df.drop(neg_duration, inplace= True)
df.head(10)
# Out:
#     session_id  customer_id login_date projects_added likes_given  \
# 0     624205.0      80746.0   10/30/19          False        True
# 1     624241.0      24520.0   10/30/19           True        True
# 2     111002.0      32047.0   10/30/19           True        True
# 3     545113.0      23404.0   10/30/19           True        True
# 4     750269.0      40235.0   10/30/19           True        True
# 6     922001.0      12407.0   10/30/19           True       False
# 8     490096.0      40572.0   10/30/19           True        True
# 10    696187.0      98653.0   10/29/19          False       False
# 12    175035.0      87323.0   10/29/19           True        True
# 13    361637.0      51243.0   10/29/19           True        True
#
#    comment_given inactive_status bug_occured  session_projects_added  \
# 0           True            True       False                     0.0
# 1           True            True       False                     2.0
# ...

# %%
Tuesday = df[df.login_date=='10/6/19']
#Tuesday1 = df[ df.login_date== '10/13/19']
             #,'10/20/19'
             #,'10/27/19']
Tuesday
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 241    366662.0      76530.0    10/6/19          False        True
# 244    704918.0      87265.0    10/6/19           True        True
# 246    225470.0      43549.0    10/6/19          False        True
# 247    419580.0      93464.0    10/6/19           True        True
# 248    563300.0      23579.0    10/6/19          False        True
# 250    356244.0      98653.0    10/6/19           True        True
# 251    133256.0      10246.0    10/6/19           True        True
# 252    611819.0      38459.0    10/6/19           True        True
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 241          True            True        True                     0.0
# 244          True            True       False                     2.0
# 246          True            True        True                     0.0
# 247         False            True       False                     3.0
# ...

# %%
repeat=df[df['customer_id'] != df['customer_id'] ].index
df.drop(repeat, inplace= True)
df.head(300)
plt.bar(df['session_comments_given'],df['duration_time'],color='r')
plt.xlabel('session_comments_given')
plt.ylabel('duration')
plt.show()
plt.bar(df['bugs_in_session'],df['duration_time'])
plt.xlabel('bugs_in_session')
plt.ylabel('duration')
plt.show()
plt.bar(df['session_likes_given'],df['duration_time'],color ='g')
plt.xlabel('session_likes_given')
plt.ylabel('duration')
plt.show()
plt.bar(df['session_projects_added'],df['duration_time'],color ='y')
plt.xlabel('session_projects_added')
plt.ylabel('duration')
plt.show()

# %%
customer = df[df.customer_id== 38459]
customer
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 15     920267.0      38459.0   10/29/19          False        True
# 47     871478.0      38459.0   10/26/19           True        True
# 64     516003.0      38459.0   10/24/19           True        True
# 87     123453.0      38459.0   10/22/19           True        True
# 124    826119.0      38459.0   10/19/19          False        True
# 146    156847.0      38459.0   10/15/19           True        True
# 162    299736.0      38459.0   10/14/19          False       False
# 167    810196.0      38459.0   10/13/19          False        True
# 180     23570.0      38459.0   10/12/19          False        True
# 229    872877.0      38459.0    10/7/19           True        True
# 252    611819.0      38459.0    10/6/19           True        True
# 263    266445.0      38459.0    10/5/19           True        True
# 268    585849.0      38459.0    10/4/19           True       False
# ...

# %%
#nobugs = df[df.bugs_in_session == 0]
nobugs = Tuesday[Tuesday['bugs_in_session'] == 0]
nobugs
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 244    704918.0      87265.0    10/6/19           True        True
# 247    419580.0      93464.0    10/6/19           True        True
# 248    563300.0      23579.0    10/6/19          False        True
# 250    356244.0      98653.0    10/6/19           True        True
# 252    611819.0      38459.0    10/6/19           True        True
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 244          True            True       False                     2.0
# 247         False            True       False                     3.0
# 248          True           False       False                     0.0
# 250          True           False       False                     2.0
# 252          True            True       False                     1.0
#
#      session_likes_given  session_comments_given  inactive_duration  \
# 244                 17.0                     4.0              850.0
# ...

# %%
tuesday = df[df.login_date=='10/13/19']
tuesday
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 163    820853.0      29375.0   10/13/19           True       False
# 164    403173.0      98476.0   10/13/19           True       False
# 165    436046.0      51243.0   10/13/19           True        True
# 166    929826.0      23083.0   10/13/19           True        True
# 167    810196.0      38459.0   10/13/19          False        True
# 168    102797.0      23985.0   10/13/19          False        True
# 169    608120.0      14354.0   10/13/19           True        True
# 170    574792.0      29375.0   10/13/19           True        True
# 171    315117.0      40572.0   10/13/19           True       False
# 173    848857.0      80746.0   10/13/19           True       False
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 163          True           False       False                     1.0
# 164          True           False       False                     2.0
# ...

# %%
def select_columns(data_frame, column_names):
    new_frame = data_frame.loc[:, column_names]
    return new_frame
selected_columns = ['session_projects_added','session_comments_given', 'bugs_in_session','session_likes_given','duration_time']
newtue = select_columns(tuesday, selected_columns)

newtue

#ax = newtue.plot.bar(rot=0)
# Out:
#      session_projects_added  session_comments_given  bugs_in_session  \
# 163                     1.0                     3.0              0.0
# 164                     2.0                     1.0              0.0
# 165                     2.0                     2.0              0.0
# 166                     3.0                     0.0              1.0
# 167                     0.0                     0.0              4.0
# 168                     0.0                     5.0              5.0
# 169                     2.0                     1.0              4.0
# 170                     1.0                     4.0              2.0
# 171                     1.0                     2.0              5.0
# 173                     3.0                     3.0              4.0
#
#      session_likes_given  duration_time
# 163                  0.0         1115.0
# 164                  0.0         2051.0
# 165                 19.0          326.0
# 166                 25.0          396.0
# ...

# %%
plt.bar(newtue['session_comments_given'],newtue['duration_time'],color='r')
plt.xlabel('newtuesession_comments_given')
plt.ylabel('duration')
plt.show()
plt.bar(newtue['bugs_in_session'],newtue['duration_time'])
plt.xlabel('newtuebugs_in_session')
plt.ylabel('duration')
plt.show()
plt.bar(newtue['session_likes_given'],newtue['duration_time'],color ='g')
plt.xlabel('newtuesession_likes_given')
plt.ylabel('duration')
plt.show()
plt.bar(newtue['session_projects_added'],newtue['duration_time'],color ='y')
plt.xlabel('newtuesession_projects_added')
plt.ylabel('duration')
plt.show()

# %%
#login_date = df[] 
df['Week']=pd.to_datetime(df['login_date'])
start_date='10/1/19'
end_date='10/30/19'
Week=(df['Week']>start_date )& (df['Week']< end_date)
df=df.loc[Week]
df
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 10     696187.0      98653.0   10/29/19          False       False
# 12     175035.0      87323.0   10/29/19           True        True
# 13     361637.0      51243.0   10/29/19           True        True
# 15     920267.0      38459.0   10/29/19          False        True
# 18     614943.0      14354.0   10/28/19           True        True
# 19     590435.0      43549.0   10/28/19           True        True
# 20     211059.0      39475.0   10/28/19           True        True
# 22     636263.0      87323.0   10/28/19           True        True
# 23     311965.0      51243.0   10/28/19           True        True
# 24     997629.0      12496.0   10/28/19           True        True
# 25     308860.0      43057.0   10/28/19           True        True
# 26     601606.0      87265.0   10/27/19           True        True
# 28     440820.0      29375.0   10/27/19          False       False
# ...

# %%
Friday = df[df.login_date=='10/23/19']
#'10/02/19','10/09/19','10/16/19'
Friday
# Out:
#     session_id  customer_id login_date projects_added likes_given  \
# 73    287401.0      87265.0   10/23/19           True        True
# 75    480779.0      34574.0   10/23/19           True        True
# 76    552796.0      39475.0   10/23/19           True        True
#
#    comment_given inactive_status bug_occured  session_projects_added  \
# 73          True           False       False                     3.0
# 75          True           False        True                     5.0
# 76          True           False        True                     1.0
#
#     session_likes_given  session_comments_given  inactive_duration  \
# 73                 24.0                     1.0                0.0
# 75                 11.0                     3.0                0.0
# 76                  2.0                     2.0                0.0
#
#     bugs_in_session  session_duration  duration_time       Week
# 73              0.0            2220.0         2220.0 2019-10-23
# ...

# %%
Friday02 = df[df.login_date=='10/02/19']
Friday09 = df[df.login_date=='10/09/19']
Friday16 = df[df.login_date=='10/16/19']

# %%
plt.bar(Friday['session_projects_added'],Friday['duration_time'])
plt.xlabel('session_projects_added')
plt.ylabel('duration')
plt.bar(Friday02['session_projects_added'],Friday02['duration_time'])

plt.bar(Friday09['session_projects_added'],Friday09['duration_time'])

plt.bar(Friday16['session_projects_added'],Friday16['duration_time'])
plt.show()

# %%
Sat =df[df.login_date=='10/24/19']
Sat
# Out:
#     session_id  customer_id login_date projects_added likes_given  \
# 61    848849.0      87323.0   10/24/19           True        True
# 62     74484.0      51243.0   10/24/19          False        True
# 63    643406.0      23083.0   10/24/19           True        True
# 64    516003.0      38459.0   10/24/19           True        True
# 68    393781.0      87265.0   10/24/19           True        True
# 70    162379.0      43549.0   10/24/19          False       False
# 72    950427.0      43057.0   10/24/19           True        True
#
#    comment_given inactive_status bug_occured  session_projects_added  \
# 61          True           False       False                     3.0
# 62          True           False       False                     0.0
# 63          True           False       False                     1.0
# 64          True            True       False                     6.0
# 68          True           False       False                     2.0
# ...

# %%
plt.bar(Friday['session_projects_added'],Friday['duration_time'])
plt.xlabel('session_projects_added')
plt.ylabel('duration')
#plt.show()

plt.bar(Sat['session_projects_added'],Sat['duration_time'])
plt.xlabel('session_projects_added')
plt.ylabel('duration')
plt.show()

# %%
plt.bar(Friday['session_comments_given'],Friday['duration_time'])
plt.xlabel('comments')
plt.ylabel('duration')
#plt.show()

plt.bar(Sat['session_comments_given'],Sat['duration_time'])
plt.xlabel('comments')
plt.ylabel('duration')
plt.show()

# %%
x= df['login_date']
y= df['duration_time']
plt.bar(x,y)
plt.xlabel('Date')
plt.xticks(rotation=60)
plt.ylabel('duration')
plt.show()

# %%
plt.bar(df['bugs_in_session'],df['duration_time'])
plt.xlabel('bugs')
plt.ylabel('duration')
plt.show()

# %%
plt.bar(df['session_comments_given'],df['duration_time'])
plt.xlabel('comments')
plt.ylabel('duration')
plt.show()

# %%
plt.bar(df['session_projects_added'],df['duration_time'])
plt.xlabel('session_projects_added')
plt.ylabel('duration')
plt.show()
plt.bar(df['login_date'],df['duration_time'])
plt.xticks(rotation=60)
plt.xlabel('login_date')
plt.ylabel('duration')
plt.show()
plt.bar(df['session_likes_given'],df['duration_time'])
plt.xlabel('session_likes_given')
plt.ylabel('duration')
plt.show()

# %%
nosession_likes_given = df[df.session_likes_given== 0]
#nosession_likes_given

#plt.bar(df['nosession_likes_given'],df['duration_time'])
plt.bar(nosession_likes_given['session_projects_added'],nosession_likes_given['duration_time'])
plt.xlabel('session_projects_added with 0 likes')
plt.ylabel('duration')
plt.show()
plt.bar(nosession_likes_given['session_comments_given'],nosession_likes_given['duration_time'])
plt.xticks(rotation=60)
plt.xlabel('session_comments_given with 0 likes')
plt.ylabel('duration')
plt.show()
plt.bar(nosession_likes_given['bugs_in_session'],nosession_likes_given['duration_time'])
plt.xlabel('bugs_in_session with 0 likes')
plt.ylabel('duration')
plt.show()

# %%
nobug = df[df.bugs_in_session== 0]
plt.bar(nobug['session_projects_added'],nobug['duration_time'])
plt.xlabel('session_projects_added with 0 bugs')
plt.ylabel('duration')
plt.show()
plt.bar(nobug['session_comments_given'],nobug['duration_time'])
plt.xticks(rotation=60)
plt.xlabel('session_comments_given with 0 bugs')
plt.ylabel('duration')
plt.show()
plt.bar(nobug['session_likes_given'],nobug['duration_time'])
plt.xlabel('session likes with 0 bugs')
plt.ylabel('duration')
plt.show()

# %%
noproj = df[df.session_projects_added== 0]
plt.bar(noproj['bugs_in_session'],noproj['duration_time'])
plt.xlabel('bugs_in_session  0 proj')
plt.ylabel('duration')
plt.show()
plt.bar(noproj['session_comments_given'],noproj['duration_time'])
plt.xticks(rotation=60)
plt.xlabel('session_comments_given with  0 proj')
plt.ylabel('duration')
plt.show()
plt.bar(noproj['session_likes_given'],noproj['duration_time'])
plt.xlabel('session likes with 0 proj')
plt.ylabel('duration')
plt.show()

# %%
nolikes = df[df.session_likes_given== 0]
plt.bar(nolikes['bugs_in_session'],nolikes['duration_time'])
plt.xlabel('bugs_in_session  0 likes')
plt.ylabel('duration')
plt.show()
plt.bar(nolikes['session_comments_given'],nolikes['duration_time'])
plt.xticks(rotation=60)
plt.xlabel('session_comments_given with  0 likes')
plt.ylabel('duration')
plt.show()
plt.bar(nolikes ['session_projects_added'],nolikes ['duration_time'])
plt.xlabel('session added with 0 likes')
plt.ylabel('duration')
plt.show()

# %%
plt.bar(df['login_date'],df['bugs_in_session'])
plt.xlabel('date')
plt.ylabel('bugs')
plt.xticks(rotation=60)
plt.show()
plt.bar(df['login_date'],df['session_comments_given'])
plt.xlabel('date')
plt.ylabel('comments')
plt.xticks(rotation=60)
plt.show()
plt.bar(df['login_date'],df['session_likes_given'])
plt.xlabel('date')
plt.ylabel('likes')
plt.xticks(rotation=60)
plt.show()
plt.bar(df['login_date'],df['session_projects_added'])
plt.xlabel('date')
plt.ylabel('proj')
plt.xticks(rotation=60)
plt.show()
plt.scatter(df['customer_id'],df['duration_time'])
plt.xticks(rotation=60)
plt.show()
